# %%
import pandas as pd
import numpy as np
import seaborn as sns
from scipy import stats
from pathlib import Path
from datetime import datetime

# Geometry libraries
import geopandas as gpd
from shapely.geometry import Polygon, LineString, Point
import psycopg2

from sqlalchemy import create_engine

ROOT = Path.cwd()

# %%
DataDir = ROOT / "Data"

# %%
norm_temperatureDF = pd.read_csv(DataDir / "Normalized/norm_temperatureDF.csv")
norm_chlorophyllDF = pd.read_csv(DataDir / "Normalized/norm_chlorophyllDF.csv")
norm_aisDF = pd.read_csv(DataDir / "Normalized/norm_aisDF.csv")
norm_fishingDF = pd.read_csv(DataDir / "Normalized/norm_fishingDF.csv")

# %%
norm_temperatureDF.head()
# Out:
#          time  latitude  longitude  temperature partOfTheDay  normLat  normLon
# 0  2020-01-01    -35.25     -69.75   288.169121          day    109.0    220.0
# 1  2020-01-01    -35.25     -69.25   288.169121          day    109.0    221.0
# 2  2020-01-01    -35.25     -68.75   288.169121          day    109.0    222.0
# 3  2020-01-01    -35.25     -68.25   288.169121          day    109.0    223.0
# 4  2020-01-01    -35.25     -67.75   288.169121          day    109.0    224.0

# %%
norm_chlorophyllDF.head()
# Out:
#          time  latitude  longitude  chlor_a  normLat  normLon
# 0  2020-01-01    -35.25     -69.75     1.04    109.0    220.0
# 1  2020-01-01    -35.25     -69.25     1.04    109.0    221.0
# 2  2020-01-01    -35.25     -68.75     1.04    109.0    222.0
# 3  2020-01-01    -35.25     -68.25     1.04    109.0    223.0
# 4  2020-01-01    -35.25     -67.75     1.04    109.0    224.0

# %%
norm_aisDF.head()
# Out:
#   BoatName  BoatID                 Date  Latitude  Longitude  normLat  normLon
# 0    Mason     111  2020-01-01 08:00:00 -38.03500  -57.52777    103.0    244.0
# 1    Mason     111  2020-01-01 12:00:00 -38.03527  -57.52777    103.0    244.0
# 2    Mason     111  2020-01-02 08:00:00 -38.03500  -57.52777    103.0    244.0
# 3    Mason     111  2020-01-02 12:00:00 -38.03500  -57.52777    103.0    244.0
# 4    Mason     111  2020-01-02 23:00:00 -38.03500  -57.52777    103.0    244.0

# %%
norm_fishingDF.head()
# Out:
#   BoatName  BoatID    Trip         Day     Kg  Duration  Lines  Temperature  \
# 0    Mason     111  2020-1  2020-01-12  11492        12     60         14.5
# 1    Mason     111  2020-1  2020-01-13  10582        12     60         14.5
# 2    Mason     111  2020-1  2020-01-18  21164        12     60         13.5
# 3    Mason     111  2020-1  2020-01-19  18980        12     60         14.0
# 4    Mason     111  2020-1  2020-01-20  16796        12     60         13.7
#
#     Latitude  Longitude  normLat  normLon
# 0 -45.100000 -62.000000     89.0    236.0
# 1 -45.033333 -62.100000     89.0    235.0
# 2 -44.833333 -63.816667     90.0    232.0
# 3 -44.833333 -63.833333     90.0    232.0
# 4 -44.866667 -63.816667     90.0    232.0

# %%
norm_tempDF_simply = norm_temperatureDF.groupby(by=["time","normLat","normLon"]).mean().reset_index()
norm_tempDF_simply
# Out:
#               time  normLat  normLon  latitude  longitude  temperature
# 0       2020-01-01     80.0    220.0    -49.75     -69.75   288.169121
# 1       2020-01-01     80.0    221.0    -49.75     -69.25   288.169121
# 2       2020-01-01     80.0    222.0    -49.75     -68.75   288.169121
# 3       2020-01-01     80.0    223.0    -49.75     -68.25   288.169121
# 4       2020-01-01     80.0    224.0    -49.75     -67.75   288.169121
# ...            ...      ...      ...       ...        ...          ...
# 218395  2020-06-30    109.0    255.0    -35.25     -52.25   288.169121
# 218396  2020-06-30    109.0    256.0    -35.25     -51.75   288.169121
# 218397  2020-06-30    109.0    257.0    -35.25     -51.25   288.169121
# 218398  2020-06-30    109.0    258.0    -35.25     -50.75   288.169121
# 218399  2020-06-30    109.0    259.0    -35.25     -50.25   288.169121
#
# [218400 rows x 6 columns]

# %% [markdown]
# ## Convert the pandas dataframe to geoPandas dataframe

# %%
geoFishingDF = gpd.GeoDataFrame(norm_fishingDF, 
                                geometry=gpd.points_from_xy(norm_fishingDF.normLat, norm_fishingDF.normLon),
                                crs = "EPSG:3857")
geoFishingDF = geoFishingDF[["BoatName", "BoatID", "Day", "Kg", "Duration", "Lines", "Temperature", "geometry"]]
geoFishingDF.head() # 644 x 7
# Out:
#   BoatName  BoatID         Day     Kg  Duration  Lines  Temperature  \
# 0    Mason     111  2020-01-12  11492        12     60         14.5
# 1    Mason     111  2020-01-13  10582        12     60         14.5
# 2    Mason     111  2020-01-18  21164        12     60         13.5
# 3    Mason     111  2020-01-19  18980        12     60         14.0
# 4    Mason     111  2020-01-20  16796        12     60         13.7
#
#                  geometry
# 0  POINT (89.000 236.000)
# 1  POINT (89.000 235.000)
# 2  POINT (90.000 232.000)
# 3  POINT (90.000 232.000)
# 4  POINT (90.000 232.000)

# %%
geoTemperatureDF = gpd.GeoDataFrame(norm_tempDF_simply, 
                                geometry=gpd.points_from_xy(norm_tempDF_simply.normLat, norm_tempDF_simply.normLon),
                                crs = "EPSG:3857")
geoTemperatureDF = geoTemperatureDF[["time", "temperature", "geometry"]]
geoTemperatureDF.head() # 218400 x 4
# Out:
#          time  temperature                geometry
# 0  2020-01-01   288.169121  POINT (80.000 220.000)
# 1  2020-01-01   288.169121  POINT (80.000 221.000)
# 2  2020-01-01   288.169121  POINT (80.000 222.000)
# 3  2020-01-01   288.169121  POINT (80.000 223.000)
# 4  2020-01-01   288.169121  POINT (80.000 224.000)

# %%
geoChlorophyllDF = gpd.GeoDataFrame(norm_chlorophyllDF, 
                                geometry=gpd.points_from_xy(norm_chlorophyllDF.normLat, norm_chlorophyllDF.normLon),
                                crs = "EPSG:3857")
geoChlorophyllDF = geoChlorophyllDF[["time", "chlor_a", "geometry"]]
geoChlorophyllDF.head() # 218400 x 3
# Out:
#          time  chlor_a                 geometry
# 0  2020-01-01     1.04  POINT (109.000 220.000)
# 1  2020-01-01     1.04  POINT (109.000 221.000)
# 2  2020-01-01     1.04  POINT (109.000 222.000)
# 3  2020-01-01     1.04  POINT (109.000 223.000)
# 4  2020-01-01     1.04  POINT (109.000 224.000)

# %%
boatMap_Name_ID = geoFishingDF[["BoatName", "BoatID"]].drop_duplicates().reset_index(drop=True)
boatMap_Name_ID
# Out:
#   BoatName  BoatID
# 0    Mason     111
# 1      Rey     112
# 2   Korbin     113
# 3   Armani     114
# 4   Rodney     115

# %%
geoFeatures = geoTemperatureDF.copy()
geoFeatures = geoFeatures.merge(geoChlorophyllDF, on=["time", "geometry"])
geoFeatures.head()

#for i,_ in geoFeatures.iterrows():

#    geoFeatures["chlor_a"] = geoChlorophyllDF[
#                                (geoChlorophyllDF["geometry"].intersects(geoFeatures['geometry'][i])) & 
#                                (geoFeatures["time"][i] == geoChlorophyllDF["time"])]["chlor_a"]
# Out:
#          time  temperature                geometry  chlor_a
# 0  2020-01-01   288.169121  POINT (80.000 220.000)     1.04
# 1  2020-01-01   288.169121  POINT (80.000 221.000)     1.04
# 2  2020-01-01   288.169121  POINT (80.000 222.000)     1.04
# 3  2020-01-01   288.169121  POINT (80.000 223.000)     1.04
# 4  2020-01-01   288.169121  POINT (80.000 224.000)     1.04

# %%
geoFishingDF
# Out:
#     BoatName  BoatID         Day     Kg  Duration  Lines  Temperature  \
# 0      Mason     111  2020-01-12  11492        12     60         14.5
# 1      Mason     111  2020-01-13  10582        12     60         14.5
# 2      Mason     111  2020-01-18  21164        12     60         13.5
# 3      Mason     111  2020-01-19  18980        12     60         14.0
# 4      Mason     111  2020-01-20  16796        12     60         13.7
# ..       ...     ...         ...    ...       ...    ...          ...
# 639   Rodney     115  2020-06-21  21790        12    100         11.0
# 640   Rodney     115  2020-06-22  20410        12    100         11.2
# 641   Rodney     115  2020-06-25  23330        12    100         10.3
# 642   Rodney     115  2020-06-26   8120        12    100         10.9
# 643   Rodney     115  2020-06-27   2530        12    100         10.6
#
#                    geometry
# 0    POINT (89.000 236.000)
# 1    POINT (89.000 235.000)
# 2    POINT (90.000 232.000)
# 3    POINT (90.000 232.000)
# 4    POINT (90.000 232.000)
# ..                      ...
# 639  POINT (95.000 241.000)
# 640  POINT (95.000 241.000)
# 641  POINT (95.000 241.000)
# 642  POINT (96.000 241.000)
# 643  POINT (96.000 240.000)
#
# [644 rows x 8 columns]

# %%
geoFishingDF_in = geoFishingDF.copy()
#geoFishingDF_in = geoFeatures.merge(geoFeatures, left_on=["Day"], right_on=["time"])
geoFishingDF_in = geoFishingDF_in.sjoin(geoFeatures, how="inner", predicate = "intersects")
geoFishingDF_in
# Out:
#     BoatName  BoatID         Day     Kg  Duration  Lines  Temperature  \
# 0      Mason     111  2020-01-12  11492        12     60         14.5
# 0      Mason     111  2020-01-12  11492        12     60         14.5
# 0      Mason     111  2020-01-12  11492        12     60         14.5
# 0      Mason     111  2020-01-12  11492        12     60         14.5
# 0      Mason     111  2020-01-12  11492        12     60         14.5
# ..       ...     ...         ...    ...       ...    ...          ...
# 631   Rodney     115  2020-06-13  30130        12    100         10.1
# 633   Rodney     115  2020-06-15   5580        12    100          9.2
# 629   Rodney     115  2020-06-06  17720        12    100         10.2
# 631   Rodney     115  2020-06-13  30130        12    100         10.1
# 633   Rodney     115  2020-06-15   5580        12    100          9.2
#
#                    geometry  index_right        time  temperature  chlor_a
# 0    POINT (89.000 236.000)        51976  2020-02-13   288.169121     1.04
# 0    POINT (89.000 236.000)       207976  2020-06-22   288.169121     1.04
# 0    POINT (89.000 236.000)        72376  2020-03-01   288.169121     1.04
# 0    POINT (89.000 236.000)          376  2020-01-01   288.169121     1.04
# 0    POINT (89.000 236.000)        65176  2020-02-24   288.169121     1.04
# ..                      ...          ...         ...          ...      ...
# 631  POINT (93.000 240.000)       160140  2020-05-13   288.169121     1.04
# 633  POINT (93.000 240.000)       160140  2020-05-13   288.169121     1.04
# 629  POINT (93.000 240.000)        44940  2020-02-07   288.169121     1.04
# 631  POINT (93.000 240.000)        44940  2020-02-07   288.169121     1.04
# 633  POINT (93.000 240.000)        44940  2020-02-07   288.169121     1.04
#
# [117208 rows x 12 columns]

# %%
geoFishingDF_in["temperature"] = geoFishingDF_in["temperature"] - 273.15
geoFishingDF_in
# Out:
#     BoatName  BoatID         Day     Kg  Duration  Lines  Temperature  \
# 0      Mason     111  2020-01-12  11492        12     60         14.5
# 0      Mason     111  2020-01-12  11492        12     60         14.5
# 0      Mason     111  2020-01-12  11492        12     60         14.5
# 0      Mason     111  2020-01-12  11492        12     60         14.5
# 0      Mason     111  2020-01-12  11492        12     60         14.5
# ..       ...     ...         ...    ...       ...    ...          ...
# 631   Rodney     115  2020-06-13  30130        12    100         10.1
# 633   Rodney     115  2020-06-15   5580        12    100          9.2
# 629   Rodney     115  2020-06-06  17720        12    100         10.2
# 631   Rodney     115  2020-06-13  30130        12    100         10.1
# 633   Rodney     115  2020-06-15   5580        12    100          9.2
#
#                    geometry  index_right        time  temperature  chlor_a
# 0    POINT (89.000 236.000)        51976  2020-02-13    15.019121     1.04
# 0    POINT (89.000 236.000)       207976  2020-06-22    15.019121     1.04
# 0    POINT (89.000 236.000)        72376  2020-03-01    15.019121     1.04
# 0    POINT (89.000 236.000)          376  2020-01-01    15.019121     1.04
# 0    POINT (89.000 236.000)        65176  2020-02-24    15.019121     1.04
# ..                      ...          ...         ...          ...      ...
# 631  POINT (93.000 240.000)       160140  2020-05-13    15.019121     1.04
# 633  POINT (93.000 240.000)       160140  2020-05-13    15.019121     1.04
# 629  POINT (93.000 240.000)        44940  2020-02-07    15.019121     1.04
# 631  POINT (93.000 240.000)        44940  2020-02-07    15.019121     1.04
# 633  POINT (93.000 240.000)        44940  2020-02-07    15.019121     1.04
#
# [117208 rows x 12 columns]

# %%
geoFishingDF_filtered = geoFishingDF_in[geoFishingDF_in["Day"] == geoFishingDF_in["time"]]
geoFishingDF_filtered = geoFishingDF_filtered[["BoatName", "BoatID", "Day", "Kg", "Duration", "Temperature", "temperature", "chlor_a", "geometry"]]
geoFishingDF_filtered.sort_values(by=["BoatID", "Day"], inplace=True)
geoFishingDF_filtered.reset_index(drop=True, inplace=True)
geoFishingDF_filtered
# Out:
#     BoatName  BoatID         Day     Kg  Duration  Temperature  temperature  \
# 0      Mason     111  2020-01-12  11492        12         14.5    15.019121
# 1      Mason     111  2020-01-13  10582        12         14.5    15.019121
# 2      Mason     111  2020-01-18  21164        12         13.5    15.019121
# 3      Mason     111  2020-01-19  18980        12         14.0    15.019121
# 4      Mason     111  2020-01-20  16796        12         13.7    15.019121
# ..       ...     ...         ...    ...       ...          ...          ...
# 639   Rodney     115  2020-06-21  21790        12         11.0    15.019121
# 640   Rodney     115  2020-06-22  20410        12         11.2    15.019121
# 641   Rodney     115  2020-06-25  23330        12         10.3    15.019121
# 642   Rodney     115  2020-06-26   8120        12         10.9    15.019121
# 643   Rodney     115  2020-06-27   2530        12         10.6    15.019121
#
#      chlor_a                geometry
# 0       1.04  POINT (89.000 236.000)
# 1       1.04  POINT (89.000 235.000)
# 2       1.04  POINT (90.000 232.000)
# 3       1.04  POINT (90.000 232.000)
# 4       1.04  POINT (90.000 232.000)
# ..       ...                     ...
# 639     1.04  POINT (95.000 241.000)
# 640     1.04  POINT (95.000 241.000)
# 641     1.04  POINT (95.000 241.000)
# 642     1.04  POINT (96.000 241.000)
# 643     1.04  POINT (96.000 240.000)
#
# [644 rows x 9 columns]

# %% [markdown]
# # fnrwiofnoiramfpoamfpoeam,fopam,fpoea,fea,

# %%
geoFishingDF
# Out:
#     BoatName  BoatID         Day     Kg  Duration  Lines  \
# 0      Mason     111  2020-01-12  11492        12     60
# 1      Mason     111  2020-01-13  10582        12     60
# 2      Mason     111  2020-01-18  21164        12     60
# 3      Mason     111  2020-01-19  18980        12     60
# 4      Mason     111  2020-01-20  16796        12     60
# ..       ...     ...         ...    ...       ...    ...
# 639   Rodney     115  2020-06-21  21790        12    100
# 640   Rodney     115  2020-06-22  20410        12    100
# 641   Rodney     115  2020-06-25  23330        12    100
# 642   Rodney     115  2020-06-26   8120        12    100
# 643   Rodney     115  2020-06-27   2530        12    100
#
#                    geometry
# 0    POINT (89.000 236.000)
# 1    POINT (89.000 235.000)
# 2    POINT (90.000 232.000)
# 3    POINT (90.000 232.000)
# 4    POINT (90.000 232.000)
# ..                      ...
# 639  POINT (95.000 241.000)
# 640  POINT (95.000 241.000)
# 641  POINT (95.000 241.000)
# 642  POINT (96.000 241.000)
# 643  POINT (96.000 240.000)
#
# [644 rows x 7 columns]

# %%
geoFishingDF[""]
for i, _ in geoFishingDF

# %%
# Out:
# C:\Users\enriq\AppData\Local\Temp\ipykernel_32336\3726370355.py:1: FutureWarning: Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.
#   geoTemperatureDF.groupby(by=["time", "geometry"]).mean()
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\algorithms.py:1735, in safe_sort(values, codes, na_sentinel, assume_unique, verify)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=1733'>1734</a> try:
# -> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=1734'>1735</a>     sorter = values.argsort()
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=1735'>1736</a>     ordered = values.take(sorter)
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\arrays\base.py:672, in ExtensionArray.argsort(self, ascending, kind, na_position, *args, **kwargs)
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/arrays/base.py?line=669'>670</a> ascending = nv.validate_argsort_with_ascending(ascending, args, kwargs)
# --> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/arrays/base.py?line=671'>672</a> values = self._values_for_argsort()
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/arrays/base.py?line=672'>673</a> return nargsort(
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/arrays/base.py?line=673'>674</a>     values,
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/arrays/base.py?line=674'>675</a>     kind=kind,
#    (...)
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/arrays/base.py?line=677'>678</a>     mask=np.asarray(self.isna()),
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/arrays/base.py?line=678'>679</a> )
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\geopandas\array.py:1231, in GeometryArray._values_for_argsort(self)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/geopandas/array.py?line=1229'>1230</a> # Note: this is used in `ExtensionArray.argsort`.
# -> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/geopandas/array.py?line=1230'>1231</a> raise TypeError("geometries are not orderable")
#
# TypeError: geometries are not orderable
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# d:\00.Mis_Cosas\Universidad\Master\Q2\DMT\Project\Project2_Processing&Querying_TransportationData\Code\dataIntegration.ipynb Cell 16' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/00.Mis_Cosas/Universidad/Master/Q2/DMT/Project/Project2_Processing%26Querying_TransportationData/Code/dataIntegration.ipynb#ch0000019?line=0'>1</a> geoTemperatureDF.groupby(by=["time", "geometry"]).mean()
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\groupby\groupby.py:1956, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=1953'>1954</a>     return self._numba_agg_general(sliding_mean, engine_kwargs, "groupby_mean")
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=1954'>1955</a> else:
# -> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=1955'>1956</a>     result = self._cython_agg_general(
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=1956'>1957</a>         "mean",
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=1957'>1958</a>         alt=lambda x: Series(x).mean(numeric_only=numeric_only_bool),
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=1958'>1959</a>         numeric_only=numeric_only_bool,
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=1959'>1960</a>     )
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=1960'>1961</a>     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\groupby\groupby.py:1597, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=1593'>1594</a> if not is_ser and len(new_mgr) < len(data):
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=1594'>1595</a>     warn_dropping_nuisance_columns_deprecated(type(self), how)
# -> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=1596'>1597</a> res = self._wrap_agged_manager(new_mgr)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=1597'>1598</a> if is_ser:
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=1598'>1599</a>     res.index = self.grouper.result_index
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\groupby\generic.py:1434, in DataFrameGroupBy._wrap_agged_manager(self, mgr)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/generic.py?line=1431'>1432</a>     result = result._consolidate()
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/generic.py?line=1432'>1433</a> else:
# -> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/generic.py?line=1433'>1434</a>     index = self.grouper.result_index
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/generic.py?line=1434'>1435</a>     mgr.set_axis(1, index)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/generic.py?line=1435'>1436</a>     result = self.obj._constructor(mgr)
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\_libs\properties.pyx:37, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\groupby\ops.py:895, in BaseGrouper.result_index(self)
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=891'>892</a> if len(self.groupings) == 1:
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=892'>893</a>     return self.groupings[0].result_index.rename(self.names[0])
# --> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=894'>895</a> codes = self.reconstructed_codes
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=895'>896</a> levels = [ping.result_index for ping in self.groupings]
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=896'>897</a> return MultiIndex(
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=897'>898</a>     levels=levels, codes=codes, verify_integrity=False, names=self.names
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=898'>899</a> )
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\groupby\ops.py:871, in BaseGrouper.reconstructed_codes(self)
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=868'>869</a> @property
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=869'>870</a> def reconstructed_codes(self) -> list[np.ndarray]:
# --> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=870'>871</a>     codes = self.codes
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=871'>872</a>     ids, obs_ids, _ = self.group_info
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=872'>873</a>     return decons_obs_group_ids(ids, obs_ids, self.shape, codes, xnull=True)
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\groupby\ops.py:793, in BaseGrouper.codes(self)
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=789'>790</a> @final
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=790'>791</a> @property
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=791'>792</a> def codes(self) -> list[np.ndarray]:
# --> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=792'>793</a>     return [ping.codes for ping in self.groupings]
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\groupby\ops.py:793, in <listcomp>(.0)
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=789'>790</a> @final
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=790'>791</a> @property
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=791'>792</a> def codes(self) -> list[np.ndarray]:
# --> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/ops.py?line=792'>793</a>     return [ping.codes for ping in self.groupings]
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\groupby\grouper.py:622, in Grouping.codes(self)
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/grouper.py?line=617'>618</a> if self._codes is not None:
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/grouper.py?line=618'>619</a>     # _codes is set in __init__ for MultiIndex cases
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/grouper.py?line=619'>620</a>     return self._codes
# --> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/grouper.py?line=621'>622</a> return self._codes_and_uniques[0]
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\_libs\properties.pyx:37, in pandas._libs.properties.CachedProperty.__get__()
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\groupby\grouper.py:690, in Grouping._codes_and_uniques(self)
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/grouper.py?line=687'>688</a>     else:
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/grouper.py?line=688'>689</a>         na_sentinel = -1
# --> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/grouper.py?line=689'>690</a>     codes, uniques = algorithms.factorize(
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/grouper.py?line=690'>691</a>         self.grouping_vector, sort=self._sort, na_sentinel=na_sentinel
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/grouper.py?line=691'>692</a>     )
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/grouper.py?line=692'>693</a> return codes, uniques
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\algorithms.py:768, in factorize(values, sort, na_sentinel, size_hint)
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=762'>763</a>     codes, uniques = factorize_array(
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=763'>764</a>         values, na_sentinel=na_sentinel, size_hint=size_hint, na_value=na_value
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=764'>765</a>     )
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=766'>767</a> if sort and len(uniques) > 0:
# --> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=767'>768</a>     uniques, codes = safe_sort(
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=768'>769</a>         uniques, codes, na_sentinel=na_sentinel, assume_unique=True, verify=False
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=769'>770</a>     )
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=771'>772</a> code_is_na = codes == na_sentinel
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=772'>773</a> if not dropna and code_is_na.any():
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=773'>774</a>     # na_value is set based on the dtype of uniques, and compat set to False is
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=774'>775</a>     # because we do not want na_value to be 0 for integers
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\algorithms.py:1744, in safe_sort(values, codes, na_sentinel, assume_unique, verify)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=1741'>1742</a>             ordered = _sort_tuples(values)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=1742'>1743</a>         else:
# -> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=1743'>1744</a>             ordered = _sort_mixed(values)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=1745'>1746</a> # codes:
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=1747'>1748</a> if codes is None:
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\algorithms.py:1796, in _sort_mixed(values)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=1793'>1794</a> """order ints before strings in 1d arrays, safe in py3"""
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=1794'>1795</a> str_pos = np.array([isinstance(x, str) for x in values], dtype=bool)
# -> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=1795'>1796</a> nums = np.sort(values[~str_pos])
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=1796'>1797</a> strs = np.sort(values[str_pos])
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/algorithms.py?line=1797'>1798</a> return np.concatenate([nums, np.asarray(strs, dtype=object)])
#
# File <__array_function__ internals>:180, in sort(*args, **kwargs)
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\numpy\core\fromnumeric.py:1004, in sort(a, axis, kind, order)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/numpy/core/fromnumeric.py?line=1001'>1002</a> else:
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/numpy/core/fromnumeric.py?line=1002'>1003</a>     a = asanyarray(a).copy(order="K")
# -> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/numpy/core/fromnumeric.py?line=1003'>1004</a> a.sort(axis=axis, kind=kind, order=order)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/numpy/core/fromnumeric.py?line=1004'>1005</a> return a
#
# TypeError: '<' not supported between instances of 'Point' and 'Point'

# %%
geoTemperatureDF.dissolve(by=["time"], aggfunc='mean')
#geoFishingDF.dissolve(by=["BoatID","Day"], aggfunc='mean')
#day = geoFishingDF["Day"][0]

#for i,_ in geoFishingDF.iterrows():
#    day = geoFishingDF["Day"][i]
# Out:
#               time  temperature partOfTheDay                 geometry
# 0       2020-01-01   288.169121          day  POINT (109.000 220.000)
# 1       2020-01-01   288.169121          day  POINT (109.000 221.000)
# 2       2020-01-01   288.169121          day  POINT (109.000 222.000)
# 3       2020-01-01   288.169121          day  POINT (109.000 223.000)
# 4       2020-01-01   288.169121          day  POINT (109.000 224.000)
# ...            ...          ...          ...                      ...
# 436795  2020-06-30   288.169121        night   POINT (80.000 255.000)
# 436796  2020-06-30   288.169121        night   POINT (80.000 256.000)
# 436797  2020-06-30   288.169121        night   POINT (80.000 257.000)
# 436798  2020-06-30   288.169121        night   POINT (80.000 258.000)
# 436799  2020-06-30   288.169121        night   POINT (80.000 259.000)
#
# [436800 rows x 4 columns]

# %%
geoTemperatureDF.dissolve(by=["time", "partOfTheDay"], aggfunc='mean')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\00.Mis_Cosas\Universidad\Master\Q2\DMT\Project\Project2_Processing&Querying_TransportationData\Code\dataIntegration.ipynb Cell 15' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/d%3A/00.Mis_Cosas/Universidad/Master/Q2/DMT/Project/Project2_Processing%26Querying_TransportationData/Code/dataIntegration.ipynb#ch0000016?line=0'>1</a> geoTemperatureDF.dissolve(by=["time", "partOfTheDay", "geometry"], aggfunc='mean')
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\geopandas\geodataframe.py:1531, in GeoDataFrame.dissolve(self, by, aggfunc, as_index, level, sort, observed, dropna)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/geopandas/geodataframe.py?line=1528'>1529</a> # Process non-spatial component
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/geopandas/geodataframe.py?line=1529'>1530</a> data = self.drop(labels=self.geometry.name, axis=1)
# -> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/geopandas/geodataframe.py?line=1530'>1531</a> aggregated_data = data.groupby(**groupby_kwargs).agg(aggfunc)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/geopandas/geodataframe.py?line=1532'>1533</a> # Process spatial component
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/geopandas/geodataframe.py?line=1533'>1534</a> def merge_geometries(block):
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/frame.py?line=7706'>7707</a> axis = self._get_axis_number(axis)
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/frame.py?line=7708'>7709</a> # https://github.com/python/mypy/issues/7642
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/frame.py?line=7709'>7710</a> # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/frame.py?line=7710'>7711</a> # "Union[bool, NoDefault]"; expected "bool"
# -> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/frame.py?line=7711'>7712</a> return DataFrameGroupBy(
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/frame.py?line=7712'>7713</a>     obj=self,
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/frame.py?line=7713'>7714</a>     keys=by,
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/frame.py?line=7714'>7715</a>     axis=axis,
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/frame.py?line=7715'>7716</a>     level=level,
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/frame.py?line=7716'>7717</a>     as_index=as_index,
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/frame.py?line=7717'>7718</a>     sort=sort,
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/frame.py?line=7718'>7719</a>     group_keys=group_keys,
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/frame.py?line=7719'>7720</a>     squeeze=squeeze,  # type: ignore[arg-type]
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/frame.py?line=7720'>7721</a>     observed=observed,
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/frame.py?line=7721'>7722</a>     dropna=dropna,
#    <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/frame.py?line=7722'>7723</a> )
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\groupby\groupby.py:882, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, observed, mutated, dropna)
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=878'>879</a> if grouper is None:
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=879'>880</a>     from pandas.core.groupby.grouper import get_grouper
# --> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=881'>882</a>     grouper, exclusions, obj = get_grouper(
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=882'>883</a>         obj,
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=883'>884</a>         keys,
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=884'>885</a>         axis=axis,
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=885'>886</a>         level=level,
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=886'>887</a>         sort=sort,
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=887'>888</a>         observed=observed,
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=888'>889</a>         mutated=self.mutated,
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=889'>890</a>         dropna=self.dropna,
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=890'>891</a>     )
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=892'>893</a> self.obj = obj
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/groupby.py?line=893'>894</a> self.axis = obj._get_axis_number(axis)
#
# File c:\Users\enriq\anaconda3\envs\geo_env\lib\site-packages\pandas\core\groupby\grouper.py:882, in get_grouper(obj, key, axis, level, sort, observed, mutated, validate, dropna)
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/grouper.py?line=879'>880</a>         in_axis, level, gpr = False, gpr, None
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/grouper.py?line=880'>881</a>     else:
# --> <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/grouper.py?line=881'>882</a>         raise KeyError(gpr)
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/grouper.py?line=882'>883</a> elif isinstance(gpr, Grouper) and gpr.key is not None:
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/grouper.py?line=883'>884</a>     # Add key to exclusions
#     <a href='file:///c%3A/Users/enriq/anaconda3/envs/geo_env/lib/site-packages/pandas/core/groupby/grouper.py?line=884'>885</a>     exclusions.add(gpr.key)
#
# KeyError: 'geometry'

# %%
geoDF = geoFishingDF.sjoin(geoTemperatureDF, how='inner', predicate='intersects')
geoDF.drop(["BoatID","index_right"], axis=1)
# Out:
#     BoatName         Day     Kg  Duration  Lines                geometry  \
# 0      Mason  2020-01-12  11492        12     60  POINT (89.000 236.000)
# 0      Mason  2020-01-12  11492        12     60  POINT (89.000 236.000)
# 0      Mason  2020-01-12  11492        12     60  POINT (89.000 236.000)
# 0      Mason  2020-01-12  11492        12     60  POINT (89.000 236.000)
# 0      Mason  2020-01-12  11492        12     60  POINT (89.000 236.000)
# ..       ...         ...    ...       ...    ...                     ...
# 631   Rodney  2020-06-13  30130        12    100  POINT (93.000 240.000)
# 633   Rodney  2020-06-15   5580        12    100  POINT (93.000 240.000)
# 629   Rodney  2020-06-06  17720        12    100  POINT (93.000 240.000)
# 631   Rodney  2020-06-13  30130        12    100  POINT (93.000 240.000)
# 633   Rodney  2020-06-15   5580        12    100  POINT (93.000 240.000)
#
#            time  temperature partOfTheDay
# 0    2020-05-04   288.169121        night
# 0    2020-05-25   288.169121          day
# 0    2020-04-30   288.169121        night
# 0    2020-04-26   288.169121          day
# 0    2020-05-27   288.169121        night
# ..          ...          ...          ...
# 631  2020-02-16   288.169121          day
# 633  2020-02-16   288.169121          day
# 629  2020-04-23   288.169121        night
# 631  2020-04-23   288.169121        night
# 633  2020-04-23   288.169121        night
#
# [234416 rows x 9 columns]
